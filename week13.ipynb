# %% [markdown]
# <a href="https://colab.research.google.com/github/B10956048/113_Finance/blob/main/week13.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf
import numpy as np

# %%
# 股票列表和時間範圍
stock_symbols = ['AAPL', 'MSFT', 'GOOGL', 'AMZN', 'TSLA', 'META', 'NFLX', 'NVDA', 'JPM', 'V']
start_date = '2020-01-01'
end_date = '2023-01-01'

# 獲取歷史數據
def fetch_stock_data(symbols, start, end):
    data = yf.download(symbols, start=start, end=end)['Adj Close']
    return data

# 計算每日回報率、年化回報率和年化風險
def calculate_returns_and_risk(data):
    daily_returns = data.pct_change().dropna()
    annual_returns = daily_returns.mean() * 252  # 年化回報率
    annual_risks = daily_returns.std() * np.sqrt(252)  # 年化風險
    correlation_matrix = daily_returns.corr()  # 相關性矩陣
    return annual_returns, annual_risks, correlation_matrix

# 適應函數
def fitness_function(portfolio, annual_returns, annual_risks, correlation_matrix):
    if sum(portfolio) == 0:  # 確保至少選擇一個資產
        return -np.inf
    portfolio_return = np.dot(portfolio, annual_returns)
    covariance_matrix = np.outer(annual_risks, annual_risks) * correlation_matrix
    portfolio_variance = np.dot(portfolio, np.dot(covariance_matrix, portfolio))
    portfolio_risk = np.sqrt(portfolio_variance)
    if portfolio_risk == 0:
        return -np.inf
    sharpe_ratio = portfolio_return / portfolio_risk
    return sharpe_ratio

# 基因演算法的實現
def genetic_algorithm(data, pop_size, num_generations, mutation_rate):
    annual_returns, annual_risks, correlation_matrix = calculate_returns_and_risk(data)
    num_assets = len(data.columns)

    # 初始種群生成（權重化）
    population = np.random.dirichlet(np.ones(num_assets), pop_size)  # 每個個體權重總和為 1
    best_solution = None
    best_fitness = -np.inf

    for generation in range(num_generations):
        fitness_scores = np.array([
            fitness_function(ind, annual_returns, annual_risks, correlation_matrix)
            for ind in population
        ])
        new_population = []

        # 選擇過程（輪盤選擇）
        probabilities = (fitness_scores - fitness_scores.min()) + 1e-6  # 避免負數或零
        probabilities /= probabilities.sum()
        for _ in range(pop_size // 2):
            parent1 = population[np.random.choice(len(population), p=probabilities)]
            parent2 = population[np.random.choice(len(population), p=probabilities)]

            # 單點交叉
            crossover_point = np.random.randint(1, num_assets - 1)
            child1 = np.concatenate((parent1[:crossover_point], parent2[crossover_point:]))
            child2 = np.concatenate((parent2[:crossover_point], parent1[crossover_point:]))

            # 突變
            child1 = mutate(child1, mutation_rate)
            child2 = mutate(child2, mutation_rate)

            # 確保權重總和為 1
            child1 /= child1.sum()
            child2 /= child2.sum()
            new_population.extend([child1, child2])

        population = np.array(new_population)
        current_best = population[np.argmax(fitness_scores)]
        current_best_fitness = max(fitness_scores)

        if current_best_fitness > best_fitness:
            best_solution = current_best
            best_fitness = current_best_fitness

        print(f"Generation {generation + 1}: Best Fitness = {best_fitness:.4f}")

    return best_solution, best_fitness, annual_returns, annual_risks, correlation_matrix


# 突變函數
def mutate(child, mutation_rate):
    for i in range(len(child)):
        if np.random.rand() < mutation_rate:
            child[i] += np.random.normal(0, 0.1)  # 添加小的隨機波動
    child = np.maximum(0, child)  # 確保權重非負
    return child

# %%
# 執行程式
stock_data = fetch_stock_data(stock_symbols, start_date, end_date)
print(stock_data)
best_portfolio, best_fitness, annual_returns, annual_risks, correlation_matrix = genetic_algorithm(
    stock_data, pop_size=100, num_generations=100, mutation_rate=0.1
)

# 結果輸出
selected_assets = [stock_symbols[i] for i in range(len(best_portfolio)) if best_portfolio[i] > 0.01]
portfolio_return = np.dot(best_portfolio, annual_returns)
cov_matrix = np.outer(annual_risks, annual_risks) * correlation_matrix
portfolio_var = np.dot(best_portfolio, np.dot(cov_matrix, best_portfolio))
portfolio_risk = np.sqrt(portfolio_var)

print("\n最佳投資組合:")
print(f"選擇的股票: {selected_assets}")
print(f"權重: {best_portfolio}")
print(f"回報率: {portfolio_return:.4f}")
print(f"風險: {portfolio_risk:.4f}")
print(f"夏普比率: {best_fitness:.4f}")
# Out:
# [*********************100%***********************]  10 of 10 completed
# Ticker            AAPL       AMZN      GOOGL         JPM        META  \
# Date
# 2020-01-02   72.796021  94.900497  68.186813  122.104614  209.150269
# 2020-01-03   72.088310  93.748497  67.830116  120.493263  208.043610
# 2020-01-06   72.662704  95.143997  69.638054  120.397438  211.961807
# 2020-01-07   72.320976  95.343002  69.503548  118.350616  212.420410
# 2020-01-08   73.484352  94.598503  69.998253  119.273903  214.573944
# ...                ...        ...        ...         ...         ...
# 2022-12-23  130.487808  85.250000  88.907700  124.506897  117.685661
# 2022-12-27  128.676834  83.040001  87.074348  124.943161  116.529144
# 2022-12-28  124.728355  81.820000  85.709297  125.626007  115.272926
# 2022-12-29  128.261200  84.180000  88.130516  126.346802  119.899002
# 2022-12-30  128.577866  84.000000  87.911316  127.181366  119.978760
#
# Ticker            MSFT        NFLX       NVDA        TSLA           V
# Date
# 2020-01-02  153.630661  329.809998   5.972710   28.684000  184.487305
# 2020-01-03  151.717697  325.899994   5.877112   29.534000  183.020081
# 2020-01-06  152.109848  335.829987   5.901758   30.102667  182.624268
# 2020-01-07  150.722992  330.750000   5.973208   31.270666  182.141663
# 2020-01-08  153.123779  339.260010   5.984412   32.809334  185.259537
# ...                ...         ...        ...         ...         ...
# 2022-12-23  234.875427  294.959991  15.194947  123.150002  202.659317
# 2022-12-27  233.134003  284.170013  14.110738  109.099998  203.112198
# 2022-12-28  230.743271  276.880005  14.025798  112.709999  201.832260
# 2022-12-29  237.118607  291.119995  14.592387  121.820000  204.854950
# 2022-12-30  235.947845  294.880005  14.603378  123.180000  204.559570
#
# [756 rows x 10 columns]
# Generation 1: Best Fitness = 0.9110
# Generation 2: Best Fitness = 0.9426
# Generation 3: Best Fitness = 0.9898
# Generation 4: Best Fitness = 0.9898
# Generation 5: Best Fitness = 0.9898
# Generation 6: Best Fitness = 0.9898
# Generation 7: Best Fitness = 0.9992
# Generation 8: Best Fitness = 1.0251
# Generation 9: Best Fitness = 1.0292
# Generation 10: Best Fitness = 1.0292
# Generation 11: Best Fitness = 1.0292
# Generation 12: Best Fitness = 1.0379
# Generation 13: Best Fitness = 1.0540
# Generation 14: Best Fitness = 1.0604
# Generation 15: Best Fitness = 1.0721
# Generation 16: Best Fitness = 1.0721
# Generation 17: Best Fitness = 1.0721
# Generation 18: Best Fitness = 1.0735
# Generation 19: Best Fitness = 1.0735
# Generation 20: Best Fitness = 1.0741
# Generation 21: Best Fitness = 1.0741
# Generation 22: Best Fitness = 1.0741
# Generation 23: Best Fitness = 1.0741
# Generation 24: Best Fitness = 1.0742
# Generation 25: Best Fitness = 1.0742
# Generation 26: Best Fitness = 1.0742
# Generation 27: Best Fitness = 1.0756
# Generation 28: Best Fitness = 1.0756
# Generation 29: Best Fitness = 1.0756
# Generation 30: Best Fitness = 1.0756
# Generation 31: Best Fitness = 1.0756
# Generation 32: Best Fitness = 1.0756
# Generation 33: Best Fitness = 1.0756
# Generation 34: Best Fitness = 1.0756
# Generation 35: Best Fitness = 1.0756
# Generation 36: Best Fitness = 1.0756
# Generation 37: Best Fitness = 1.0756
# Generation 38: Best Fitness = 1.0756
# Generation 39: Best Fitness = 1.0756
# Generation 40: Best Fitness = 1.0757
# Generation 41: Best Fitness = 1.0757
# Generation 42: Best Fitness = 1.0757
# Generation 43: Best Fitness = 1.0757
# Generation 44: Best Fitness = 1.0757
# Generation 45: Best Fitness = 1.0757
# Generation 46: Best Fitness = 1.0757
# Generation 47: Best Fitness = 1.0757
# Generation 48: Best Fitness = 1.0757
# Generation 49: Best Fitness = 1.0757
# Generation 50: Best Fitness = 1.0757
# Generation 51: Best Fitness = 1.0757
# Generation 52: Best Fitness = 1.0757
# Generation 53: Best Fitness = 1.0757
# Generation 54: Best Fitness = 1.0757
# Generation 55: Best Fitness = 1.0757
# Generation 56: Best Fitness = 1.0757
# Generation 57: Best Fitness = 1.0757
# Generation 58: Best Fitness = 1.0757
# Generation 59: Best Fitness = 1.0757
# Generation 60: Best Fitness = 1.0757
# Generation 61: Best Fitness = 1.0757
# Generation 62: Best Fitness = 1.0757
# Generation 63: Best Fitness = 1.0757
# Generation 64: Best Fitness = 1.0757
# Generation 65: Best Fitness = 1.0757
# Generation 66: Best Fitness = 1.0757
# Generation 67: Best Fitness = 1.0757
# Generation 68: Best Fitness = 1.0757
# Generation 69: Best Fitness = 1.0757
# Generation 70: Best Fitness = 1.0757
# Generation 71: Best Fitness = 1.0757
# Generation 72: Best Fitness = 1.0757
# Generation 73: Best Fitness = 1.0757
# Generation 74: Best Fitness = 1.0757
# Generation 75: Best Fitness = 1.0757
# Generation 76: Best Fitness = 1.0757
# Generation 77: Best Fitness = 1.0757
# Generation 78: Best Fitness = 1.0757
# Generation 79: Best Fitness = 1.0757
# Generation 80: Best Fitness = 1.0757
# Generation 81: Best Fitness = 1.0757
# Generation 82: Best Fitness = 1.0757
# Generation 83: Best Fitness = 1.0757
# Generation 84: Best Fitness = 1.0757
# Generation 85: Best Fitness = 1.0757
# Generation 86: Best Fitness = 1.0757
# Generation 87: Best Fitness = 1.0757
# Generation 88: Best Fitness = 1.0757
# Generation 89: Best Fitness = 1.0757
# Generation 90: Best Fitness = 1.0757
# Generation 91: Best Fitness = 1.0757
# Generation 92: Best Fitness = 1.0757
# Generation 93: Best Fitness = 1.0757
# Generation 94: Best Fitness = 1.0757
# Generation 95: Best Fitness = 1.0757
# Generation 96: Best Fitness = 1.0757
# Generation 97: Best Fitness = 1.0757
# Generation 98: Best Fitness = 1.0757
# Generation 99: Best Fitness = 1.0757
# Generation 100: Best Fitness = 1.0757
#
# 最佳投資組合:
# 選擇的股票: ['AAPL', 'GOOGL', 'AMZN', 'NFLX', 'NVDA', 'JPM']
# 權重: [0.04474114 0.00845806 0.01967381 0.07782484 0.         0.
#  0.03622653 0.18424158 0.62883404 0.        ]
# 回報率: 0.5787
# 風險: 0.5534
# 夏普比率: 1.0757
